# %%
def pagar_divida(valor_divida, pagamento_mensal):
    pagamento = 1

    while valor_divida > 0:
        valor_anterior = valor_divida
        valor_divida -= pag_mensal

        if valor_divida < 0:
            valor_divida = 0

valor_divida = int(input())
pag_mensal = int(input())
i = 0

if valor_divida < pag_mensal:
  i += 1
  print('pagamento:',i)
  print('antes =',valor_divida)
  print('depois = 0')
  print('-----')
else:
    while valor_divida >= pag_mensal:
      i += 1
      mensalidade = valor_divida
      valor_divida = mensalidade - pag_mensal
      print('pagamento',i)
      print('antes =', mensalidade)
      print('depois =',valor_divida)
      print('-----')
      if valor_divida >= pag_mensal:
        continue

      elif valor_divida > 0:
          i += 1
          print('pagamento',i)
          print('antes = ',valor_divida)
          print('depois = 0 ')
          print('-----')

pagar_divida(valor_divida, pag_mensal)
# Out:
# 300
# 50
# pagamento 1
# antes = 300
# depois = 250
# -----
# pagamento 2
# antes = 250
# depois = 200
# -----
# pagamento 3
# antes = 200
# depois = 150
# -----
# pagamento 4
# antes = 150
# depois = 100
# -----
# pagamento 5
# antes = 100
# depois = 50
# -----
# pagamento 6
# antes = 50
# depois = 0
# -----

# %%
def pagar_divida(valor_divida, pagamento_mensal):
    pagamento = 1

    while valor_divida > 0:
        valor_anterior = valor_divida
        valor_divida -= pagamento_mensal

        if valor_divida < 0:
            valor_divida = 0

        print(f'Pagamento {pagamento}: Antes = {valor_anterior}, Depois = {valor_divida}')

        pagamento += 1

valor_divida = int(input())
pagamento_mensal = int(input())

pagar_divida(valor_divida, pagamento_mensal)
# Out:
# Informe o valor total da dívida: 300
# Informe o valor do pagamento mensal: 50
# Pagamento 1: Antes = 300, Depois = 250
# Pagamento 2: Antes = 250, Depois = 200
# Pagamento 3: Antes = 200, Depois = 150
# Pagamento 4: Antes = 150, Depois = 100
# Pagamento 5: Antes = 100, Depois = 50
# Pagamento 6: Antes = 50, Depois = 0
