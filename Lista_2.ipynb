# %%
# Exercício 10
import numpy as np 
import matplotlib.pyplot as plt
V0= 10
g= 9.81
t= np.linspace(0, (2*V0)/g)
y= V0*t - ((g*t**2)/2)
plt.plot(t,y)

# %%
# Exercício 1
primos = [2,3,5,7,11,13]
p = [17]
print(primos)
N_primos = [ primos + p for i in range(len(p)) ]
N_primos
# Out:
# [2, 3, 5, 7, 11, 13]
# [[2, 3, 5, 7, 11, 13, 17]]

# %%
#Exercício 7
import matplotlib.pyplot as plt 
import numpy as np
x= np.linspace(-4,4,51)
h= []
for c in x:
  y=(1/np.sqrt(2*np.pi)) * np.exp(-((c**2)/2))
  h.append(y)
print(h)
# Out:
# [0.00013383022576488537, 0.00025057844489086075, 0.00045731481405985675, 0.0008135212310818084, 0.0014106022569413848, 0.0023840882014648404, 0.003927553628924779, 0.0063067263962659275, 0.009871153794751144, 0.01505961632737745, 0.0223945302948429, 0.032460265643697445, 0.04586107627105489, 0.06315656143519865, 0.08477636130802226, 0.11092083467945554, 0.14145996522483878, 0.17584743029766242, 0.21306914677571784, 0.2516443410981171, 0.2896915527614828, 0.3250622640840821, 0.3555325285059971, 0.3790305261527017, 0.3938683615685408, 0.3989422804014327, 0.3938683615685408, 0.37903052615270166, 0.35553252850599704, 0.3250622640840822, 0.2896915527614828, 0.2516443410981171, 0.21306914677571784, 0.1758474302976623, 0.1414599652248387, 0.11092083467945546, 0.08477636130802226, 0.06315656143519865, 0.04586107627105489, 0.032460265643697445, 0.022394530294842882, 0.01505961632737743, 0.009871153794751144, 0.0063067263962659275, 0.003927553628924779, 0.0023840882014648404, 0.001410602256941
# ...

# %%
# Exercício 5
x= 15
if 0 <= x <= 2:
  print(f'{x}=x**2')
elif 2 < x <= 4:
  print(f'{x}=4')
elif x < 0:
  print(f'{x}=0')
else:
  print(f'{x}= -15')
# Out:
# 15= -15

# %%
# Exercício 3
q = [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h']]
print(q)

procurar = 'a'
for i in q:
    local = q.index(i) 
    for b in i:
        if b == procurar:
            local2 = q[local].index(b) 
            print("Quem você procura está na posição: lista[{}][{}]".format(local,local2))
            break
procurar1 = 'h'
for i in q:
    local = q.index(i) 
    for b in i:
        if b == procurar1:
            local2 = q[local].index(b) 
            print("Quem você procura está na posição: lista[{}][{}]".format(local,local2))
            break
procurar2 = 'd'
for i in q:
    local = q.index(i) 
    for b in i:
        if b == procurar2:
            local2 = q[local].index(b) 
            print("Quem você procura está na posição: lista[{}][{}]".format(local,local2))
            break
procurar3 = 'g'
for i in q:
    local = q.index(i) 
    for b in i:
        if b == procurar3:
            local2 = q[local].index(b) 
            print("Quem você procura está na posição: lista[{}][{}]".format(local,local2))
            break
print(q[1][0],q[1][1],q[1][2])
# Out:
# [['a', 'b', 'c'], ['d', 'e', 'f'], ['g', 'h']]
# Quem você procura está na posição: lista[0][0]
# Quem você procura está na posição: lista[2][1]
# Quem você procura está na posição: lista[1][0]
# Quem você procura está na posição: lista[2][0]
# d e f

# %%
#Exercício 8
import matplotlib.pyplot as plt 
import numpy as np
x= np.linspace(-4,4,51)
y= (1/np.sqrt(2*np.pi)) * np.exp(-((x**2)/2))
plt.plot(x,y)

# %%
#Exercício 9
import numpy as np
v= [3,2,-1]
V1=np.array(v)
V2= []
x= t**3 + t * np.exp(t) + 1
for c in V1:
  x= c**3 + c * np.exp(c) + 1
  V2.append(x)
V3= tuple(V2)
print(V3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7234e3946419> in <module>()
#       4 V1=np.array(v)
#       5 V2= []
# ----> 6 x= t**3 + t * np.exp(t) + 1
#       7 for c in V1:
#       8   x= c**3 + c * np.exp(c) + 1
#
# NameError: name 't' is not defined

# %%
#Exercício 2
c=1
n= int(input('digite o seu número:'))
while c<n+1:
  print(c)
  c= c + 2
# Out:
# digite o seu número:8
# 1
# 3
# 5
# 7

# %%
#Exercício 4
V1= []
V2= []
V3= []
x1, y1 = eval(input('digite os vertices:')), eval(input('digite os vertices:'))
x2, y2 = eval(input('digite os vertices:')), eval(input('digite os vertices:'))
x3, y3 = eval(input('digite os vertices:')), eval(input('digite os vertices:'))
print()
print()
#print(x1, y1)
V1.append(x1)
V1.append(y1)
V2.append(x2)
V2.append(y2)
V3.append(x3)
V3.append(y3)
#print(V1)
#print(V2)
#print(V3)
vertices=[V1, V2, V3]
area= ((y1*x3+x2*y3)-(x3*y2+y3*x1))/2
print(
    f'Os vertices do triângulo são {vertices}.\n'
    f'A área do triângulo é {area}.'
)
#print(vertices)
#print(area)
# Out:
# digite os vertices:7
# digite os vertices:7
# digite os vertices:4
# digite os vertices:5
# digite os vertices:6
# digite os vertices:8
#
#
# Os vertices do triângulo são [[7, 7], [4, 5], [6, 8]].
# A área do triângulo é -6.0.

# %%
q= []
l1= ['a','b','c']
l2= ['d','e','f']
l3= ['g','h']
q.append(l1)
q.append(l2)
q.append(l3)
print(q)

# %%
#exercício 6
import numpy as np
def f(x,m,n,r,s):
  x = float(input('x = ?'))
  if x :
    print(1)
  else:
    x != 1
    x = ((e**r*x)*np.sin*m*x) + ((e**s*x)*np.sin*n*x)

#for m,n,r,s * x
#if true
#return x/ para m,n,r,s considerar
#input tipo float? ou n?, condição falsa
#return x=1?
